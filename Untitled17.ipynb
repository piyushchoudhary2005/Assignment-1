# %% [markdown]
# <a href="https://colab.research.google.com/github/piyushchoudhary2005/Assignment-1/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""
UK-DALE NILM Mini Project — Multi-Model Comparison
=====================================================
Models compared:
  1. Random Forest Regressor  (original)
  2. XGBoost Regressor
  3. Support Vector Regressor (SVR)

Metrics: MAE, RMSE, R²
"""

# ─────────────────────────────────────────────
# 1.  INSTALL DEPENDENCIES
# ─────────────────────────────────────────────
import subprocess, sys

def install(pkg):
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", pkg])

install("h5py")
install("pandas")
install("numpy")
install("scikit-learn")
install("matplotlib")
install("xgboost")
install("gradio")
install("kagglehub")

print("✅ All dependencies installed.")

# ─────────────────────────────────────────────
# 2.  IMPORTS
# ─────────────────────────────────────────────
import os, random, time
import numpy as np
import pandas as pd
import h5py
import matplotlib.pyplot as plt
from pathlib import Path

from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error

import xgboost as xgb
import gradio as gr

SEED = 42
random.seed(SEED)
np.random.seed(SEED)

# ─────────────────────────────────────────────
# 3.  CONFIG
# ─────────────────────────────────────────────
class Config:
    UKDALE_PATH    = None
    HOUSE_IDS      = [1, 2]
    SAMPLE_PERIOD  = 6

    APPLIANCES = {
        "kettle":           10,
        "fridge":            5,
        "washing_machine":   6,
        "microwave":        13,
        "dish_washer":      22,
    }
    ON_THRESHOLDS = {
        "kettle":           2000,
        "fridge":             50,
        "washing_machine":    20,
        "microwave":         200,
        "dish_washer":        10,
    }

    WINDOW_SIZE    = 480
    STRIDE         = 120
    CHECKPOINT_DIR = "/tmp/checkpoints"
    OUTPUT_DIR     = "/tmp"
    os.makedirs(CHECKPOINT_DIR, exist_ok=True)

cfg = Config()

# ─────────────────────────────────────────────
# 4.  DOWNLOAD & LOAD DATA
# ─────────────────────────────────────────────
import kagglehub
os.makedirs("/usr/local/hdf5/lib/plugin", exist_ok=True)

path = kagglehub.dataset_download("abdelmdz/uk-dale")
cfg.UKDALE_PATH = os.path.join(path, "ukdale.h5")
print(f"✅ UK-DALE path: {cfg.UKDALE_PATH}")


def inspect_hdf5(path: str, max_depth: int = 3) -> None:
    def _walk(name, obj, depth=0):
        if depth > max_depth: return
        kind = "GROUP" if isinstance(obj, h5py.Group) else f"DATASET {obj.shape}"
        print("  " * depth + f"{name}  [{kind}]")
    print(f"\n↓️ HDF5 structure of {path}:")
    with h5py.File(path, "r") as f:
        f.visititems(lambda name, obj: _walk(name, obj, name.count("/")))

inspect_hdf5(cfg.UKDALE_PATH)


def load_ukdale(path: str) -> dict:
    if not Path(path).exists():
        raise FileNotFoundError(f"❌ File not found: '{path}'")
    print(f"📂 Loading UK-DALE from houses {cfg.HOUSE_IDS}...")

    def _read_meter(store, building: int, meter: int) -> pd.Series:
        key = f"/building{building}/elec/meter{meter}"
        if key not in store:
            raise KeyError(f"Key {key} not in store")
        df = store[key]
        for col in [("power", "active"), "power active", "active", 0]:
            if col in df.columns:
                return df[col].astype(np.float32)
        numeric_cols = df.select_dtypes(include=[np.number]).columns
        if len(numeric_cols):
            return df[numeric_cols[0]].astype(np.float32)
        raise ValueError(f"No numeric column found in {key}.")

    all_agg_vals = []
    all_app_data = {name: [] for name in cfg.APPLIANCES}

    with pd.HDFStore(path, "r") as store:
        for house_id in cfg.HOUSE_IDS:
            try:
                agg_series = _read_meter(store, house_id, 1)
                agg_vals   = agg_series.values.flatten()
                agg_time   = agg_series.index.astype(np.int64).values
                all_agg_vals.append(agg_vals)
                print(f"   House {house_id} Aggregate: {len(agg_vals):,} pts | mean={agg_vals.mean():.1f}W")
                for app_name, chan in cfg.APPLIANCES.items():
                    try:
                        app_series = _read_meter(store, house_id, chan)
                        app_vals   = app_series.values.flatten().astype(np.float32)
                        app_time   = app_series.index.astype(np.int64).values
                        aligned    = np.interp(agg_time, app_time, app_vals)
                        all_app_data[app_name].append(np.clip(aligned, 0, None))
                        print(f"   ✅ House {house_id} {app_name:<15} {len(aligned):>10,} pts")
                    except Exception as e:
                        print(f"   ⚠️  House {house_id} Skipping {app_name}: {e}")
            except Exception as e:
                print(f"   ⚠️  Skipping House {house_id}: {e}")

    if not all_agg_vals:
        raise ValueError("❌ No aggregate data loaded.")

    full_agg_vals  = np.concatenate(all_agg_vals)
    full_appliance = {n: np.concatenate(v) for n, v in all_app_data.items() if v}
    return {"aggregate": full_agg_vals, "appliances": full_appliance}


raw_data = load_ukdale(cfg.UKDALE_PATH)
print("✅ raw_data loaded.")

# Build pandas Series
times = pd.date_range(start='2013-01-01', periods=len(raw_data["aggregate"]), freq=f'{cfg.SAMPLE_PERIOD}S')
aggregate_series      = pd.Series(raw_data["aggregate"], index=times, name='aggregate_power')

target_appliance_name  = 'kettle'
target_appliance_power = pd.Series(
    raw_data['appliances'][target_appliance_name],
    index=aggregate_series.index,
    name=f'{target_appliance_name}_power'
)

# Truncate for speed
N = 100_000
aggregate_series       = aggregate_series.head(N)
target_appliance_power = target_appliance_power.head(N)
print(f"Using {N:,} samples.")

# ─────────────────────────────────────────────
# 5.  FEATURE ENGINEERING
# ─────────────────────────────────────────────
def create_rf_features(aggregate_series: pd.Series, cfg) -> pd.DataFrame:
    """Statistical, temporal, lagged, and event-based features."""
    window_size_samples = int(cfg.WINDOW_SIZE * cfg.SAMPLE_PERIOD / 60 * 60 / cfg.SAMPLE_PERIOD)
    rolling = aggregate_series.rolling(window=f'{window_size_samples}s', min_periods=1)

    df = pd.DataFrame({
        'power_mean':   rolling.mean(),
        'power_std':    rolling.std(),
        'power_min':    rolling.min(),
        'power_max':    rolling.max(),
        'power_median': rolling.median(),
        'power_skew':   rolling.skew(),
        'power_kurt':   rolling.kurt(),
        'power_rms':    np.sqrt(rolling.apply(lambda x: np.mean(x**2))),
    }, index=aggregate_series.index)

    df = df.fillna(method='bfill').fillna(method='ffill')

    df['hour_of_day']   = aggregate_series.index.hour
    df['day_of_week']   = aggregate_series.index.dayofweek
    df['month_of_year'] = aggregate_series.index.month
    df['day_of_year']   = aggregate_series.index.dayofyear
    df['is_weekend']    = (df['day_of_week'] >= 5).astype(int)
    df['hour_sin']      = np.sin(2 * np.pi * df['hour_of_day'] / 24)
    df['hour_cos']      = np.cos(2 * np.pi * df['hour_of_day'] / 24)
    df['dayofweek_sin'] = np.sin(2 * np.pi * df['day_of_week'] / 7)
    df['dayofweek_cos'] = np.cos(2 * np.pi * df['day_of_week'] / 7)

    for lag in [1, 5, 10]:
        df[f'power_lag_{lag}'] = aggregate_series.shift(lag)
    df = df.fillna(method='bfill').fillna(method='ffill')

    df['power_diff'] = aggregate_series.diff().abs()
    df['is_event']   = (df['power_diff'] > 500).astype(int)
    return df

print("🔧 Engineering features …")
rf_features = create_rf_features(aggregate_series, cfg)
print(f"   Feature matrix: {rf_features.shape}")

X = rf_features.dropna()
y = target_appliance_power.loc[X.index]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=SEED)
print(f"   Train: {X_train.shape[0]:,}   Test: {X_test.shape[0]:,}")

# ─────────────────────────────────────────────
# 6.  HELPER — train & evaluate a model
# ─────────────────────────────────────────────
def evaluate(name, model, X_tr, y_tr, X_te, y_te, scale=False):
    print(f"\n{'─'*50}\n  Training: {name}")

    scaler = None
    if scale:
        scaler = StandardScaler()
        X_tr = scaler.fit_transform(X_tr)
        X_te = scaler.transform(X_te)

    t0 = time.time()
    model.fit(X_tr, y_tr)
    train_time = time.time() - t0

    y_pred = model.predict(X_te)
    mae    = mean_absolute_error(y_te, y_pred)
    rmse   = np.sqrt(mean_squared_error(y_te, y_pred))
    r2     = r2_score(y_te, y_pred)

    print(f"  ✅ {train_time:.1f}s  |  MAE={mae:.2f}W  RMSE={rmse:.2f}W  R²={r2:.4f}")
    return {"Model": name, "MAE (W)": round(mae, 2), "RMSE (W)": round(rmse, 2),
            "R²": round(r2, 4), "Train Time (s)": round(train_time, 1),
            "predictions": y_pred, "scaler": scaler}

# ─────────────────────────────────────────────
# 7.  TRAIN ALL THREE MODELS
# ─────────────────────────────────────────────
results = []

# ── 7a. Random Forest ─────────────────────────
rf_model = RandomForestRegressor(n_estimators=100, random_state=SEED, n_jobs=-1)
results.append(evaluate("Random Forest", rf_model, X_train, y_train, X_test, y_test))

# ── 7b. XGBoost ───────────────────────────────
xgb_model = xgb.XGBRegressor(
    n_estimators=200, learning_rate=0.05, max_depth=6,
    subsample=0.8, colsample_bytree=0.8,
    random_state=SEED, n_jobs=-1, verbosity=0
)
results.append(evaluate("XGBoost", xgb_model, X_train, y_train, X_test, y_test))

# ── 7c. SVR ───────────────────────────────────
# SVR is O(n²) so we cap training samples for speed
SVR_MAX   = 20_000
svr_model = SVR(kernel='rbf', C=100, epsilon=10, gamma='scale')
results.append(evaluate(
    "SVR (RBF)", svr_model,
    X_train.iloc[:SVR_MAX], y_train.iloc[:SVR_MAX],
    X_test, y_test,
    scale=True
))

# ─────────────────────────────────────────────
# 8.  COMPARISON TABLE
# ─────────────────────────────────────────────
print(f"\n{'═'*55}")
print(f"  MODEL COMPARISON — {target_appliance_name.upper()}")
print(f"{'═'*55}")

summary = [{k: v for k, v in r.items() if k not in ("predictions", "scaler")} for r in results]
df_summary = pd.DataFrame(summary).sort_values("MAE (W)")
print(df_summary.to_string(index=False))

best_model_name = df_summary.iloc[0]["Model"]
print(f"\n🏆 Best model by MAE: {best_model_name}")

# ─────────────────────────────────────────────
# 9.  COMPARISON BAR CHARTS
# ─────────────────────────────────────────────
model_names = df_summary["Model"].tolist()
maes        = df_summary["MAE (W)"].tolist()
rmses       = df_summary["RMSE (W)"].tolist()
r2s         = df_summary["R²"].tolist()
colors      = ['#2196F3', '#4CAF50', '#FF9800']

fig, axes = plt.subplots(1, 3, figsize=(15, 5))
fig.suptitle(f"Model Comparison — {target_appliance_name.capitalize()} Power Disaggregation",
             fontsize=13, fontweight='bold')

for ax, vals, title, ylabel in zip(
    axes,
    [maes, rmses, r2s],
    ["MAE (W) — lower is better", "RMSE (W) — lower is better", "R² Score — higher is better"],
    ["MAE (W)", "RMSE (W)", "R²"]
):
    bars = ax.bar(model_names, vals, color=colors)
    ax.set_title(title, fontsize=10)
    ax.set_ylabel(ylabel)
    ax.tick_params(axis='x', rotation=15)
    for bar, val in zip(bars, vals):
        ax.text(bar.get_x() + bar.get_width() / 2,
                bar.get_height() + max(vals) * 0.01,
                f'{val:.2f}', ha='center', va='bottom', fontsize=9, fontweight='bold')

plt.tight_layout()
plt.savefig("/tmp/model_comparison.png", dpi=150, bbox_inches='tight')
plt.show()
print("✅ Comparison chart saved.")

# ─────────────────────────────────────────────
# 10. PREDICTION PLOTS — all 3 models
# ─────────────────────────────────────────────
SEG = 500
fig2, axes2 = plt.subplots(3, 1, figsize=(15, 12), sharex=False)
fig2.suptitle(f"Predicted vs Actual — {target_appliance_name.capitalize()} (first {SEG} test samples)",
              fontsize=12, fontweight='bold')

for ax, res in zip(axes2, results):
    actual = y_test.values[:SEG]
    preds  = res["predictions"][:SEG]
    ax.plot(actual, label='Actual',    alpha=0.85, linewidth=1)
    ax.plot(preds,  label='Predicted', alpha=0.85, linewidth=1, linestyle='--')
    ax.set_title(f"{res['Model']}   MAE={res['MAE (W)']}W  |  RMSE={res['RMSE (W)']}W  |  R²={res['R²']}",
                 fontsize=10)
    ax.set_ylabel("Power (W)")
    ax.legend(fontsize=9)
    ax.grid(True, alpha=0.4)

plt.tight_layout()
plt.savefig("/tmp/prediction_plots.png", dpi=120, bbox_inches='tight')
plt.show()
print("✅ Prediction plots saved.")

# ─────────────────────────────────────────────
# 11. SCATTER — best model actual vs predicted
# ─────────────────────────────────────────────
best_res  = next(r for r in results if r["Model"] == best_model_name)
y_act_b   = y_test.values
y_pred_b  = best_res["predictions"]

plt.figure(figsize=(7, 7))
plt.scatter(y_act_b, y_pred_b, alpha=0.2, s=5, color='steelblue')
lim = [min(y_act_b.min(), y_pred_b.min()), max(y_act_b.max(), y_pred_b.max())]
plt.plot(lim, lim, '--r', linewidth=2, label='Perfect Prediction')
plt.title(f'Best Model: {best_model_name}\nActual vs Predicted — {target_appliance_name.capitalize()}')
plt.xlabel('Actual Power (W)')
plt.ylabel('Predicted Power (W)')
plt.legend(); plt.grid(True, alpha=0.4)
plt.tight_layout()
plt.savefig("/tmp/best_model_scatter.png", dpi=150, bbox_inches='tight')
plt.show()

# ─────────────────────────────────────────────
# 12. GRADIO DEMO
# ─────────────────────────────────────────────
MODEL_REGISTRY = {
    "Random Forest": (rf_model,  results[0]["scaler"]),
    "XGBoost":       (xgb_model, results[1]["scaler"]),
    "SVR (RBF)":     (svr_model, results[2]["scaler"]),
}

def gradio_predict(model_name: str, start_offset_minutes: int, duration_minutes: int):
    model_obj, scaler = MODEL_REGISTRY[model_name]
    spm          = 60 / cfg.SAMPLE_PERIOD
    start_sample = int(start_offset_minutes * spm)
    end_sample   = min(int(start_sample + duration_minutes * spm), len(aggregate_series))
    start_sample = max(0, min(start_sample, end_sample - int(spm)))

    agg_seg    = aggregate_series.iloc[start_sample:end_sample]
    target_seg = target_appliance_power.iloc[start_sample:end_sample]

    feats = create_rf_features(agg_seg, cfg).dropna()
    X_seg = feats.values
    y_act = target_seg.loc[feats.index].values

    if scaler:
        X_seg = scaler.transform(X_seg)

    y_prd    = model_obj.predict(X_seg)
    mae_seg  = mean_absolute_error(y_act, y_prd)

    fig, ax = plt.subplots(figsize=(14, 5))
    ax.plot(y_act, label='Actual',    alpha=0.85)
    ax.plot(y_prd, label='Predicted', linestyle='--', alpha=0.85)
    ax.set_title(f'{model_name} — {target_appliance_name.capitalize()}  |  Segment MAE: {mae_seg:.1f}W')
    ax.set_xlabel('Sample index')
    ax.set_ylabel('Power (W)')
    ax.legend(); ax.grid(True, alpha=0.4)
    plt.tight_layout()
    return fig

demo = gr.Interface(
    fn=gradio_predict,
    inputs=[
        gr.Dropdown(choices=list(MODEL_REGISTRY.keys()), value="Random Forest", label="Model"),
        gr.Slider(0, 10000, value=0,   step=10, label="Start Offset (minutes)"),
        gr.Slider(10, 1440, value=120, step=10, label="Duration (minutes)"),
    ],
    outputs=gr.Plot(label="Disaggregation Result"),
    title="UK-DALE NILM — 3-Model Disaggregation Demo",
    description=f"Compare Random Forest, XGBoost, and SVR on {target_appliance_name} power disaggregation.",
)

demo.launch(share=True)
# Out:
# ✅ All dependencies installed.
# Downloading to /root/.cache/kagglehub/datasets/abdelmdz/uk-dale/1.archive...
# 100%|██████████| 5.06G/5.06G [00:51<00:00, 104MB/s]
# Extracting files...
# ✅ UK-DALE path: /root/.cache/kagglehub/datasets/abdelmdz/uk-dale/versions/1/ukdale.h5
#
# ↓️ HDF5 structure of /root/.cache/kagglehub/datasets/abdelmdz/uk-dale/versions/1/ukdale.h5:
# building1  [GROUP]
#   building1/elec  [GROUP]
#     building1/elec/meter1  [GROUP]
#       building1/elec/meter1/_i_table  [GROUP]
#       building1/elec/meter1/table  [DATASET (21837636,)]
#     building1/elec/meter10  [GROUP]
#       building1/elec/meter10/_i_table  [GROUP]
#       building1/elec/meter10/table  [DATASET (18881051,)]
#     building1/elec/meter11  [GROUP]
#       building1/elec/meter11/_i_table  [GROUP]
#       building1/elec/meter11/table  [DATASET (19404267,)]
#     building1/elec/meter12  [GROUP]
#       building1/elec/meter12/_i_table  [GROUP]
#       building1/elec/meter12/table  [DATASET (19381298,)]
#     building1/elec/meter13  [GROUP]
#       building1/elec/meter13/_i_table  [GROUP]
#       building1/elec/meter13/table  [DATASET (19406625,)]
#     building1/elec/meter14  [GROUP]
#       building1/elec/meter14/_i_table  [GROUP]
#       building1/elec/meter14/table  [DATASET (4143648,)]
#     building1/elec/meter15  [GROUP]
#       building1/elec/meter15/_i_table  [GROUP]
#       building1/elec/meter15/table  [DATASET (4157704,)]
#     building1/elec/meter16  [GROUP]
#       building1/elec/meter16/_i_table  [GROUP]
#       building1/elec/meter16/table  [DATASET (13351860,)]
#     building1/elec/meter17  [GROUP]
#       building1/elec/meter17/_i_table  [GROUP]
#       building1/elec/meter17/table  [DATASET (19547699,)]
#     building1/elec/meter18  [GROUP]
#       building1/elec/meter18/_i_table  [GROUP]
#       building1/elec/meter18/table  [DATASET (19116542,)]
#     building1/elec/meter19  [GROUP]
#       building1/elec/meter19/_i_table  [GROUP]
#       building1/elec/meter19/table  [DATASET (18609054,)]
#     building1/elec/meter2  [GROUP]
#       building1/elec/meter2/_i_table  [GROUP]
#       building1/elec/meter2/table  [DATASET (21281331,)]
#     building1/elec/meter20  [GROUP]
#       building1/elec/meter20/_i_table  [GROUP]
#       building1/elec/meter20/table  [DATASET (617699,)]
#     building1/elec/meter21  [GROUP]
#       building1/elec/meter21/_i_table  [GROUP]
#       building1/elec/meter21/table  [DATASET (3602216,)]
#     building1/elec/meter22  [GROUP]
#       building1/elec/meter22/_i_table  [GROUP]
#       building1/elec/meter22/table  [DATASET (134467,)]
#     building1/elec/meter23  [GROUP]
#       building1/elec/meter23/_i_table  [GROUP]
#       building1/elec/meter23/table  [DATASET (10670426,)]
#     building1/elec/meter24  [GROUP]
#       building1/elec/meter24/_i_table  [GROUP]
#       building1/elec/meter24/table  [DATASET (16218474,)]
#     building1/elec/meter25  [GROUP]
#       building1/elec/meter25/_i_table  [GROUP]
#       building1/elec/meter25/table  [DATASET (20785844,)]
#     building1/elec/meter26  [GROUP]
#       building1/elec/meter26/_i_table  [GROUP]
#       building1/elec/meter26/table  [DATASET (18618217,)]
#     building1/elec/meter27  [GROUP]
#       building1/elec/meter27/_i_table  [GROUP]
#       building1/elec/meter27/table  [DATASET (12253298,)]
#     building1/elec/meter28  [GROUP]
#       building1/elec/meter28/_i_table  [GROUP]
#       building1/elec/meter28/table  [DATASET (18645123,)]
#     building1/elec/meter29  [GROUP]
#       building1/elec/meter29/_i_table  [GROUP]
#       building1/elec/meter29/table  [DATASET (18651142,)]
#     building1/elec/meter3  [GROUP]
#       building1/elec/meter3/_i_table  [GROUP]
#       building1/elec/meter3/table  [DATASET (21281208,)]
#     building1/elec/meter30  [GROUP]
#       building1/elec/meter30/_i_table  [GROUP]
#       building1/elec/meter30/table  [DATASET (677711,)]
#     building1/elec/meter31  [GROUP]
#       building1/elec/meter31/_i_table  [GROUP]
#       building1/elec/meter31/table  [DATASET (11355561,)]
#     building1/elec/meter32  [GROUP]
#       building1/elec/meter32/_i_table  [GROUP]
#       building1/elec/meter32/table  [DATASET (18497094,)]
#     building1/elec/meter33  [GROUP]
#       building1/elec/meter33/_i_table  [GROUP]
#       building1/elec/meter33/table  [DATASET (17439431,)]
#     building1/elec/meter34  [GROUP]
#       building1/elec/meter34/_i_table  [GROUP]
#       building1/elec/meter34/table  [DATASET (17003826,)]
#     building1/elec/meter35  [GROUP]
#       building1/elec/meter35/_i_table  [GROUP]
#       building1/elec/meter35/table  [DATASET (17934605,)]
#     building1/elec/meter36  [GROUP]
#       building1/elec/meter36/_i_table  [GROUP]
#       building1/elec/meter36/table  [DATASET (17304547,)]
#     building1/elec/meter37  [GROUP]
#       building1/elec/meter37/_i_table  [GROUP]
#       building1/elec/meter37/table  [DATASET (18506920,)]
#     building1/elec/meter38  [GROUP]
#       building1/elec/meter38/_i_table  [GROUP]
#       building1/elec/meter38/table  [DATASET (12207918,)]
#     building1/elec/meter39  [GROUP]
#       building1/elec/meter39/_i_table  [GROUP]
#       building1/elec/meter39/table  [DATASET (181497,)]
#     building1/elec/meter4  [GROUP]
#       building1/elec/meter4/_i_table  [GROUP]
#       building1/elec/meter4/table  [DATASET (4539118,)]
#     building1/elec/meter40  [GROUP]
#       building1/elec/meter40/_i_table  [GROUP]
#       building1/elec/meter40/table  [DATASET (45239,)]
#     building1/elec/meter41  [GROUP]
#       building1/elec/meter41/_i_table  [GROUP]
#       building1/elec/meter41/table  [DATASET (7160,)]
#     building1/elec/meter42  [GROUP]
#       building1/elec/meter42/_i_table  [GROUP]
#       building1/elec/meter42/table  [DATASET (18185875,)]
#     building1/elec/meter43  [GROUP]
#       building1/elec/meter43/_i_table  [GROUP]
#       building1/elec/meter43/table  [DATASET (18621408,)]
#     building1/elec/meter44  [GROUP]
#       building1/elec/meter44/_i_table  [GROUP]
#       building1/elec/meter44/table  [DATASET (18327970,)]
#     building1/elec/meter45  [GROUP]
#       building1/elec/meter45/_i_table  [GROUP]
#       building1/elec/meter45/table  [DATASET (18004938,)]
#     building1/elec/meter46  [GROUP]
#       building1/elec/meter46/_i_table  [GROUP]
#       building1/elec/meter46/table  [DATASET (17820706,)]
#     building1/elec/meter47  [GROUP]
#       building1/elec/meter47/_i_table  [GROUP]
#       building1/elec/meter47/table  [DATASET (13333663,)]
#     building1/elec/meter48  [GROUP]
#       building1/elec/meter48/_i_table  [GROUP]
#       building1/elec/meter48/table  [DATASET (18179281,)]
#     building1/elec/meter49  [GROUP]
#       building1/elec/meter49/_i_table  [GROUP]
#       building1/elec/meter49/table  [DATASET (17649667,)]
#     building1/elec/meter5  [GROUP]
#       building1/elec/meter5/_i_table  [GROUP]
#       building1/elec/meter5/table  [DATASET (19555935,)]
#     building1/elec/meter50  [GROUP]
#       building1/elec/meter50/_i_table  [GROUP]
#       building1/elec/meter50/table  [DATASET (3323283,)]
#     building1/elec/meter51  [GROUP]
#       building1/elec/meter51/_i_table  [GROUP]
#       building1/elec/meter51/table  [DATASET (3391394,)]
#     building1/elec/meter52  [GROUP]
#       building1/elec/meter52/_i_table  [GROUP]
#       building1/elec/meter52/table  [DATASET (2632277,)]
#     building1/elec/meter53  [GROUP]
#       building1/elec/meter53/_i_table  [GROUP]
#       building1/elec/meter53/table  [DATASET (2977937,)]
#     building1/elec/meter54  [GROUP]
#       building1/elec/meter54/_i_table  [GROUP]
#       building1/elec/meter54/table  [DATASET (128238700,)]
#     building1/elec/meter6  [GROUP]
#       building1/elec/meter6/_i_table  [GROUP]
#       building1/elec/meter6/table  [DATASET (19819392,)]
#     building1/elec/meter7  [GROUP]
#       building1/elec/meter7/_i_table  [GROUP]
#       building1/elec/meter7/table  [DATASET (19763329,)]
#     building1/elec/meter8  [GROUP]
#       building1/elec/meter8/_i_table  [GROUP]
#       building1/elec/meter8/table  [DATASET (21449386,)]
#     building1/elec/meter9  [GROUP]
#       building1/elec/meter9/_i_table  [GROUP]
#       building1/elec/meter9/table  [DATASET (19543268,)]
# building2  [GROUP]
#   building2/elec  [GROUP]
#     building2/elec/cache  [GROUP]
#       building2/elec/cache/meter14  [GROUP]
#       building2/elec/cache/meter2  [GROUP]
#       building2/elec/cache/meter20  [GROUP]
#     building2/elec/meter1  [GROUP]
#       building2/elec/meter1/_i_table  [GROUP]
#       building2/elec/meter1/table  [DATASET (2780373,)]
#     building2/elec/meter10  [GROUP]
#       building2/elec/meter10/_i_table  [GROUP]
#       building2/elec/meter10/table  [DATASET (2089140,)]
#     building2/elec/meter11  [GROUP]
#       building2/elec/meter11/_i_table  [GROUP]
#       building2/elec/meter11/table  [DATASET (1878770,)]
#     building2/elec/meter12  [GROUP]
#       building2/elec/meter12/_i_table  [GROUP]
#       building2/elec/meter12/table  [DATASET (1686220,)]
#     building2/elec/meter13  [GROUP]
#       building2/elec/meter13/_i_table  [GROUP]
#       building2/elec/meter13/table  [DATASET (1687175,)]
#     building2/elec/meter14  [GROUP]
#       building2/elec/meter14/_i_table  [GROUP]
#       building2/elec/meter14/table  [DATASET (1687285,)]
#     building2/elec/meter15  [GROUP]
#       building2/elec/meter15/_i_table  [GROUP]
#       building2/elec/meter15/table  [DATASET (1685519,)]
#     building2/elec/meter16  [GROUP]
#       building2/elec/meter16/_i_table  [GROUP]
#       building2/elec/meter16/table  [DATASET (1685322,)]
#     building2/elec/meter17  [GROUP]
#       building2/elec/meter17/_i_table  [GROUP]
#       building2/elec/meter17/table  [DATASET (1686903,)]
#     building2/elec/meter18  [GROUP]
#       building2/elec/meter18/_i_table  [GROUP]
#       building2/elec/meter18/table  [DATASET (1677592,)]
#     building2/elec/meter19  [GROUP]
#       building2/elec/meter19/_i_table  [GROUP]
#       building2/elec/meter19/table  [DATASET (1679203,)]
#     building2/elec/meter2  [GROUP]
#       building2/elec/meter2/_i_table  [GROUP]
#       building2/elec/meter2/table  [DATASET (2804685,)]
#     building2/elec/meter20  [GROUP]
#       building2/elec/meter20/_i_table  [GROUP]
#       building2/elec/meter20/table  [DATASET (12166699,)]
#     building2/elec/meter3  [GROUP]
#       building2/elec/meter3/_i_table  [GROUP]
#       building2/elec/meter3/table  [DATASET (2805646,)]
#     building2/elec/meter4  [GROUP]
#       building2/elec/meter4/_i_table  [GROUP]
#       building2/elec/meter4/table  [DATASET (2801065,)]
#     building2/elec/meter5  [GROUP]
#       building2/elec/meter5/_i_table  [GROUP]
#       building2/elec/meter5/table  [DATASET (2806036,)]
#     building2/elec/meter6  [GROUP]
#       building2/elec/meter6/_i_table  [GROUP]
#       building2/elec/meter6/table  [DATASET (2795349,)]
#     building2/elec/meter7  [GROUP]
#       building2/elec/meter7/_i_table  [GROUP]
#       building2/elec/meter7/table  [DATASET (2094586,)]
#     building2/elec/meter8  [GROUP]
#       building2/elec/meter8/_i_table  [GROUP]
#       building2/elec/meter8/table  [DATASET (2094523,)]
#     building2/elec/meter9  [GROUP]
#       building2/elec/meter9/_i_table  [GROUP]
#       building2/elec/meter9/table  [DATASET (2080995,)]
# building3  [GROUP]
#   building3/elec  [GROUP]
#     building3/elec/meter1  [GROUP]
#       building3/elec/meter1/_i_table  [GROUP]
#       building3/elec/meter1/table  [DATASET (512327,)]
#     building3/elec/meter2  [GROUP]
#       building3/elec/meter2/_i_table  [GROUP]
#       building3/elec/meter2/table  [DATASET (515845,)]
#     building3/elec/meter3  [GROUP]
#       building3/elec/meter3/_i_table  [GROUP]
#       building3/elec/meter3/table  [DATASET (517434,)]
#     building3/elec/meter4  [GROUP]
#       building3/elec/meter4/_i_table  [GROUP]
#       building3/elec/meter4/table  [DATASET (517595,)]
#     building3/elec/meter5  [GROUP]
#       building3/elec/meter5/_i_table  [GROUP]
#       building3/elec/meter5/table  [DATASET (517957,)]
# building4  [GROUP]
#   building4/elec  [GROUP]
#     building4/elec/meter1  [GROUP]
#       building4/elec/meter1/_i_table  [GROUP]
#       building4/elec/meter1/table  [DATASET (2186446,)]
#     building4/elec/meter2  [GROUP]
#       building4/elec/meter2/_i_table  [GROUP]
#       building4/elec/meter2/table  [DATASET (2156167,)]
#     building4/elec/meter3  [GROUP]
#       building4/elec/meter3/_i_table  [GROUP]
#       building4/elec/meter3/table  [DATASET (2171770,)]
#     building4/elec/meter4  [GROUP]
#       building4/elec/meter4/_i_table  [GROUP]
#       building4/elec/meter4/table  [DATASET (2198131,)]
#     building4/elec/meter5  [GROUP]
#       building4/elec/meter5/_i_table  [GROUP]
#       building4/elec/meter5/table  [DATASET (2194864,)]
#     building4/elec/meter6  [GROUP]
#       building4/elec/meter6/_i_table  [GROUP]
#       building4/elec/meter6/table  [DATASET (2180830,)]
# building5  [GROUP]
#   building5/elec  [GROUP]
#     building5/elec/meter1  [GROUP]
#       building5/elec/meter1/_i_table  [GROUP]
#       building5/elec/meter1/table  [DATASET (1763101,)]
#     building5/elec/meter10  [GROUP]
#       building5/elec/meter10/_i_table  [GROUP]
#       building5/elec/meter10/table  [DATASET (985784,)]
#     building5/elec/meter11  [GROUP]
#       building5/elec/meter11/_i_table  [GROUP]
#       building5/elec/meter11/table  [DATASET (10215,)]
#     building5/elec/meter12  [GROUP]
#       building5/elec/meter12/_i_table  [GROUP]
#       building5/elec/meter12/table  [DATASET (985779,)]
#     building5/elec/meter13  [GROUP]
#       building5/elec/meter13/_i_table  [GROUP]
#       building5/elec/meter13/table  [DATASET (985600,)]
#     building5/elec/meter14  [GROUP]
#       building5/elec/meter14/_i_table  [GROUP]
#       building5/elec/meter14/table  [DATASET (985998,)]
#     building5/elec/meter15  [GROUP]
#       building5/elec/meter15/_i_table  [GROUP]
#       building5/elec/meter15/table  [DATASET (985856,)]
#     building5/elec/meter16  [GROUP]
#       building5/elec/meter16/_i_table  [GROUP]
#       building5/elec/meter16/table  [DATASET (984488,)]
#     building5/elec/meter17  [GROUP]
#       building5/elec/meter17/_i_table  [GROUP]
#       building5/elec/meter17/table  [DATASET (975359,)]
#     building5/elec/meter18  [GROUP]
#       building5/elec/meter18/_i_table  [GROUP]
#       building5/elec/meter18/table  [DATASET (985855,)]
#     building5/elec/meter19  [GROUP]
#       building5/elec/meter19/_i_table  [GROUP]
#       building5/elec/meter19/table  [DATASET (1842971,)]
#     building5/elec/meter2  [GROUP]
#       building5/elec/meter2/_i_table  [GROUP]
#       building5/elec/meter2/table  [DATASET (984881,)]
#     building5/elec/meter20  [GROUP]
#       building5/elec/meter20/_i_table  [GROUP]
#       building5/elec/meter20/table  [DATASET (1842883,)]
#     building5/elec/meter21  [GROUP]
#       building5/elec/meter21/_i_table  [GROUP]
#       building5/elec/meter21/table  [DATASET (1842782,)]
#     building5/elec/meter22  [GROUP]
#       building5/elec/meter22/_i_table  [GROUP]
#       building5/elec/meter22/table  [DATASET (1859593,)]
#     building5/elec/meter23  [GROUP]
#       building5/elec/meter23/_i_table  [GROUP]
#       building5/elec/meter23/table  [DATASET (1859545,)]
#     building5/elec/meter24  [GROUP]
#       building5/elec/meter24/_i_table  [GROUP]
#       building5/elec/meter24/table  [DATASET (1859562,)]
#     building5/elec/meter25  [GROUP]
#       building5/elec/meter25/_i_table  [GROUP]
#       building5/elec/meter25/table  [DATASET (79850,)]
#     building5/elec/meter26  [GROUP]
#       building5/elec/meter26/_i_table  [GROUP]
#       building5/elec/meter26/table  [DATASET (11405812,)]
#     building5/elec/meter3  [GROUP]
#       building5/elec/meter3/_i_table  [GROUP]
#       building5/elec/meter3/table  [DATASET (1845649,)]
#     building5/elec/meter4  [GROUP]
#       building5/elec/meter4/_i_table  [GROUP]
#       building5/elec/meter4/table  [DATASET (1854414,)]
#     building5/elec/meter5  [GROUP]
#       building5/elec/meter5/_i_table  [GROUP]
#       building5/elec/meter5/table  [DATASET (1840507,)]
#     building5/elec/meter6  [GROUP]
#       building5/elec/meter6/_i_table  [GROUP]
#       building5/elec/meter6/table  [DATASET (1857061,)]
#     building5/elec/meter7  [GROUP]
#       building5/elec/meter7/_i_table  [GROUP]
#       building5/elec/meter7/table  [DATASET (1851917,)]
#     building5/elec/meter8  [GROUP]
#       building5/elec/meter8/_i_table  [GROUP]
#       building5/elec/meter8/table  [DATASET (985653,)]
#     building5/elec/meter9  [GROUP]
#       building5/elec/meter9/_i_table  [GROUP]
#       building5/elec/meter9/table  [DATASET (1848688,)]
# 📂 Loading UK-DALE from houses [1, 2]...
#    House 1 Aggregate: 21,837,636 pts | mean=377.5W
#    ✅ House 1 kettle          21,837,636 pts
#    ✅ House 1 fridge          21,837,636 pts
#    ✅ House 1 washing_machine 21,837,636 pts
#    ✅ House 1 microwave       21,837,636 pts
#    ✅ House 1 dish_washer     21,837,636 pts
#    House 2 Aggregate: 2,780,373 pts | mean=337.4W
#    ✅ House 2 kettle           2,780,373 pts
#    ✅ House 2 fridge           2,780,373 pts
#    ✅ House 2 washing_machine  2,780,373 pts
#    ✅ House 2 microwave        2,780,373 pts
#    ⚠️  House 2 Skipping dish_washer: 'Key /building2/elec/meter22 not in store'
# ✅ raw_data loaded.
# Using 100,000 samples.
# 🔧 Engineering features …
# /tmp/ipykernel_4483/1736828167.py:163: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   times = pd.date_range(start='2013-01-01', periods=len(raw_data["aggregate"]), freq=f'{cfg.SAMPLE_PERIOD}S')
# /tmp/ipykernel_4483/1736828167.py:198: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='bfill').fillna(method='ffill')
# /tmp/ipykernel_4483/1736828167.py:212: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='bfill').fillna(method='ffill')
#    Feature matrix: (100000, 22)
#    Train: 79,999   Test: 20,000
#
# ──────────────────────────────────────────────────
#   Training: Random Forest
#   ✅ 95.5s  |  MAE=2.15W  RMSE=45.02W  R²=0.8981
#
# ──────────────────────────────────────────────────
#   Training: XGBoost
#   ✅ 3.6s  |  MAE=2.50W  RMSE=43.66W  R²=0.9041
#
# ──────────────────────────────────────────────────
#   Training: SVR (RBF)
#   ✅ 0.9s  |  MAE=12.01W  RMSE=129.63W  R²=0.1550
#
# ═══════════════════════════════════════════════════════
#   MODEL COMPARISON — KETTLE
# ═══════════════════════════════════════════════════════
#         Model  MAE (W)  RMSE (W)     R²  Train Time (s)
# Random Forest     2.15     45.02 0.8981            95.5
#       XGBoost     2.50     43.66 0.9041             3.6
#     SVR (RBF)    12.01    129.63 0.1550             0.9
#
# 🏆 Best model by MAE: Random Forest
# ✅ Comparison chart saved.
# ✅ Prediction plots saved.
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://e26a0a55d5d652f5fa.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://e26a0a55d5d652f5fa.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
